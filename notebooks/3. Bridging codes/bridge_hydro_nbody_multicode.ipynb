# %%
# %matplotlib notebook

"""
Hydro-Nbody coupling example in AMUSE
small gaseous clump disrupted by stellar binary system

to actually model the hydro, change 
>>> gas_code.particles.add_particles(gas)
to
>>> gas_code.gas_particles.add_particles(gas)

this version uses different codes to compute particles gravity

by Alessandro Alberto Trani 14/06/2018
"""

# comment these lines if you're using python3
from __future__ import (absolute_import, division,
                        print_function, unicode_literals)
from builtins import (
         bytes, dict, int, list, object, range, str,
         ascii, chr, hex, input, next, oct, open,
         pow, round, super,
         filter, map, zip)

from amuse.lab import *
from amuse.couple import bridge
from amuse.datamodel.particles import Channels
from amuse.ext.molecular_cloud import molecular_cloud
import matplotlib.pyplot as plt

conv=nbody_system.nbody_to_si(0.5 | units.MSun, 1 | units.RSun)

#generate initial conditions
star=Particles()
s1 = Particle(
    mass=1 | units.MSun, 
    position=(0.5, 0, 0) | units.AU, 
    velocity=(0, 21, 0) | units.km/units.s)
s2 = Particle(
    mass=1 | units.MSun, 
    position=(-0.5, 0, 0) | units.AU, 
    velocity=(0, -21, 0) | units.km/units.s)
star.add_particle(s1)
star.add_particle(s2)

gas=molecular_cloud(
    nf=32, 
    power=4, 
    targetN=1000, 
    ethep_ratio=0.001, 
    ekep_ratio=1, 
    convert_nbody=conv).result
gas.position += (-1, 1, 0) | units.AU
gas.velocity += (10, -7, 0) | units.km/units.s


#call codes and assign particles
star_code = PhiGRAPE(conv)
star_code.parameters.epsilon_squared = (1e-2 | units.RSun)**2
star_code.particles.add_particles(star)

gas_code = Fi(conv) 
gas_code.parameters.epsilon_squared = (1e-2 | units.RSun)**2
gas_code.particles.add_particles(gas) # note: gas is added as particles, not gas_particles! 
                                      #       we are not actually using hydro in order to speed up things
gas_code.parameters.integrate_entropy_flag = False
gas_code.parameters.n_smooth = 32
gas_code.parameters.periodic_box_size = 1 | units.parsec
print(gas_code.parameters)

#adding channels to copy particle sets to our framework
channel = Channels()
channel.add_channel(star_code.particles.new_channel_to(star))
channel.add_channel(gas_code.particles.new_channel_to(gas))

#set up codes to compute gas-star interactions, BHTree for gas gravity
def new_code_to_calculate_gravity_of_gas_particles():
    result = BHTree(conv)
    return result

def new_code_to_calculate_gravity_of_star_particles():
    result=Hermite(conv)
    return result

#BHTree computes the gravity of Fi particles, Hermite the gravity of PhiGRAPE particles
calculate_gravity_code_gas = bridge.CalculateFieldForCodes(
        new_code_to_calculate_gravity_of_gas_particles,
        input_codes = [gas_code])       
calculate_gravity_code_star = bridge.CalculateFieldForCodes(
        new_code_to_calculate_gravity_of_star_particles,
        input_codes = [star_code]) 

gas_to_star_codes = [calculate_gravity_code_gas]
star_to_gas_codes = [calculate_gravity_code_star]

#define an interaction timestep      
bridge_system = bridge.Bridge(timestep = 0.001 | units.yr)

#add gas, star, and interaction codes to the bridge system
bridge_system.add_system(gas_code, star_to_gas_codes)
bridge_system.add_system(star_code, gas_to_star_codes)

#plotting
fig = plt.figure(figsize=(9, 5))
ax = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

plt.ion()
fig.show()
fig.canvas.draw()

#evolve the system
tend = 1 | units.yr
dtime = 0.001 | units.yr
time = 0 | units.yr
while time < tend:
    time += dtime
    bridge_system.evolve_model(time)
    #print("evolved to time {:s}".format(time))
    channel.copy()
    
    ax.clear()
    ax2.clear()
    ax.set_ylim(-1, 1)
    ax.set_xlim(-1, 1)
    ax.set_xlabel('x [au]')
    ax.set_ylabel('y [au]')
    ax.set_aspect('equal')
    ax2.set_ylim(-1, 1)
    ax2.set_xlim(-1, 1)
    ax2.set_xlabel('x [au]')
    ax2.set_ylabel('z [au]')
    ax2.set_aspect('equal')
    ax.scatter(star.x.value_in(units.AU), star.y.value_in(units.AU))      
    ax.scatter(gas.x.value_in(units.AU), gas.y.value_in(units.AU), c = 'red', s=0.5)     
    ax.text(0.6, 0.8, "{:s}".format(time.as_quantity_in(units.yr)))
    ax2.scatter(star.x.value_in(units.AU), star.z.value_in(units.AU))      
    ax2.scatter(gas.x.value_in(units.AU), gas.z.value_in(units.AU), c = 'red', s=0.5)     
    ax2.text(0.6, 0.8, "{:s}".format(time.as_quantity_in(units.yr)))
    fig.canvas.draw()    
bridge_system.stop()
# Out:
# check random field
# check random field
# check random field
# check div-free field
# check div-free field
# check div-free field
# acc_timestep_crit_constant: 0.25 default: 0.25
# acc_timestep_flag: True default: True
# adaptive_smoothing_flag: False default: False
# artificial_viscosity_alpha: 0.5 default: 0.5
# balsara_flag: False default: False
# begin_time: 0.0 s default: 0.0 s
# beta: 1.0 default: 1.0
# code_length_unit: 695500000.0 m default: 3.08567758128e+19 m
# code_mass_unit: 9.9446e+29 kg default: 1.98892e+39 kg
# conservative_sph_flag: True default: True
# cool_par: 6.97039774737e-12 default: 1.0
# courant: 0.3 default: 0.3
# direct_sum_flag: False default: False
# enforce_min_sph_grav_softening_flag: False default: False
# eps_is_h_flag: True default: True
# epsilon_squared: 4.8372025e+13 m**2 default: 0.0 m**2
# feedback: fuv default: fuv
# fi_data_directory: /home/lex/amuse/data/fi/input/ default:
# first_snapshot: 0 default: 0
# fixed_halo_flag: False default: False
# free_timestep_crit_constant_a: 0.35 default: 0.35
# free_timestep_crit_constant_aexp: -1.0 default: -1.0
# free_timestep_crit_constant_v: 0.5 default: 0.5
# free_timestep_crit_constant_vexp: 0.0 default: 0.0
# freeform_timestep_flag: False default: False
# gadget_cell_opening_constant: 0.01 default: 0.01
# gadget_cell_opening_flag: True default: True
# gamma: 1.6666667 default: 1.6666667
# gas_epsilon: 3477500.0 m default: 3477500.0 m
# grain_heat_eff: 0.05 default: 0.05
# h_update_method: mass default: mass
# halofile: none default: none
# heat_par1: 0.0 default: 0.0
# heat_par2: 0.0 default: 0.0
# integrate_entropy_flag: False default: True
# isothermal_flag: False default: False
# log_interval: 5 default: 5
# max_density: 295594.205427 m**-3 * kg default: 295594.205427 m**-3 * kg
# maximum_time_bin: 4096 default: 4096
# min_gas_part_mass: 0.25 default: 0.25
# minimum_part_per_bin: 1 default: 1
# n_smooth: 32 default: 64
# n_smooth_tol: 0.1 default: 0.1
# nn_tol: 0.1 default: 0.1
# opening_angle: 0.5 default: 0.5
# optical_depth: 0.0 default: 0.0
# output_interval: 5 default: 5
# periodic_boundaries_flag: False default: False
# periodic_box_size: 3.08567758128e+16 m default: 6.955e+12 m
# quadrupole_moments_flag: False default: False
# radiation_flag: False default: False
# self_gravity_flag: True default: True
# smooth_input_flag: False default: False
# sph_artificial_viscosity_eps: 0.01 default: 0.01
# sph_dens_init_flag: True default: True
# sph_h_const: 139100000.0 m default: 139100000.0 m
# sph_viscosity: sph default: sph
# sqrt_timestep_crit_constant: 1.0 default: 1.0
# square_root_timestep_flag: False default: False
# star_form_delay_fac: 0.25 default: 1.0
# star_form_eff: 0.25 default: 0.25
# star_form_mass_crit: 3.97784e+35 kg default: 1.98892e+35 kg
# star_formation_flag: False default: False
# star_formation_mode: gerritsen default: gerritsen
# stopping_condition_maximum_density: inf m**-3 * kg default: -2955.94205427 m**-3 * kg
# stopping_condition_maximum_internal_energy: inf m**2 * s**-2 default: -95432127804.5 m**2 * s**-2
# stopping_condition_minimum_density: -2955.94205427 m**-3 * kg default: -2955.94205427 m**-3 * kg
# stopping_condition_minimum_internal_energy: -95432127804.5 m**2 * s**-2 default: -95432127804.5 m**2 * s**-2
# stopping_conditions_number_of_steps: 1 default: 1.0
# stopping_conditions_out_of_box_size: 0.0 m default: 0.0 m
# stopping_conditions_out_of_box_use_center_of_mass: 0 default: False
# stopping_conditions_timeout: 4.0 s default: 4.0 s
# supernova_duration: 1.326728628e+25 s default: 9.46707779808e+20 s
# supernova_eff: 0.0 default: 0.0
# t_supernova_start: 1.326728628e+24 s default: 9.46707779808e+19 s
# targetnn: 32 default: 32
# timestep: 2251.38532392 s default: 2251.38532392 s
# use_hydro_flag: True default: True
# verbosity: 0 default: 0
# zeta_cr_ion_rate: 6.48e-17 s**-1 default: 6.48e-17 s**-1
# /home/lex/amuse/src/amuse/units/generic_unit_converter.py:189: RuntimeWarning: overflow encountered in double_scalars
#   return new_quantity(number * factor, new_unit)
# <img src="data:image/png;base64,..." width="900">
# ---------------------------------------------------------------------------
# CodeException                             Traceback (most recent call last)
# <ipython-input-1-b1b7eee6062a> in <module>()
#      84 while time < tend:
#      85     time += dtime
# ---> 86     bridge_system.evolve_model(time)
#      87     #print("evolved to time {:s}".format(time))
#      88     channel.copy()
#
# /home/lex/amuse/src/amuse/couple/bridge.pyc in evolve_model(self, tend, timestep)
#     554
#     555         if self.method is None:
# --> 556             return self.evolve_joined_leapfrog(tend,timestep)
#     557         else:
#     558             return self.evolve_simple_steps(tend,timestep)
#
# /home/lex/amuse/src/amuse/couple/bridge.pyc in evolve_joined_leapfrog(self, tend, timestep)
#     569         while self.time < (tend-timestep/2.):
#     570             if first:
# --> 571                 self.kick_codes(timestep/2.)
#     572                 first=False
#     573             else:
#
# /home/lex/amuse/src/amuse/couple/bridge.pyc in kick_codes(self, dt)
#     710         for x in self.codes:
#     711             if hasattr(x,"kick"):
# --> 712                 de += x.kick(dt)
#     713
#     714         self.kick_energy += de
#
# /home/lex/amuse/src/amuse/couple/bridge.pyc in kick(self, dt)
#     456                 particles,
#     457                 field_code,
# --> 458                 dt
#     459             )
#     460
#
# /home/lex/amuse/src/amuse/couple/bridge.pyc in kick_with_field_code(self, particles, field_code, dt)
#     493             particles.x,
#     494             particles.y,
# --> 495             particles.z
#     496         )
#     497         self.update_velocities(particles, dt, ax, ay, az)
#
# /home/lex/amuse/src/amuse/couple/bridge.pyc in get_gravity_at_point(self, radius, x, y, z)
#     135
#     136     def get_gravity_at_point(self,radius,x,y,z):
# --> 137         code = self._setup_code()
#     138         try:
#     139             for input_code in self.codes_to_calculate_field_for:
#
# /home/lex/amuse/src/amuse/couple/bridge.pyc in _setup_code(self)
#     164
#     165     def _setup_code(self):
# --> 166         return self.code_factory_function()
#     167
#     168     def _cleanup_code(self, code):
#
# <ipython-input-1-b1b7eee6062a> in new_code_to_calculate_gravity_of_gas_particles()
#      47 #set up codes to compute gas-star interactions, BHTree for gas gravity
#      48 def new_code_to_calculate_gravity_of_gas_particles():
# ---> 49     result = BHTree(conv)
#      50     return result
#      51
#
# /home/lex/amuse/src/amuse/community/bhtree/interface.pyc in __init__(self, convert_nbody, **options)
#     243         self.stopping_conditions = StoppingConditions(self)
#     244
# --> 245         legacy_interface = self.__interface__(**options)
#     246
#     247         GravitationalDynamics.__init__(
#
# /home/lex/amuse/src/amuse/community/bhtree/interface.pyc in __init__(self, convert_nbody, mode, **kwargs)
#      18
#      19     def __init__(self, convert_nbody = None, mode = 'cpu', **kwargs):
# ---> 20         CodeInterface.__init__(self, name_of_the_worker=self.name_of_the_worker(mode), **kwargs)
#      21         """
#      22         self.parameters = parameters.Parameters(self.parameter_definitions, self)
#
# /home/lex/amuse/src/amuse/rfi/core.pyc in __init__(self, name_of_the_worker, **options)
#     709
#     710         if self.must_start_worker:
# --> 711             self._start(name_of_the_worker = name_of_the_worker, **options)
#     712
#     713     def __del__(self):
#
# /home/lex/amuse/src/amuse/rfi/core.pyc in _start(self, name_of_the_worker, interpreter_executable, **options)
#     728             interpreter_executable = self.interpreter
#     729
# --> 730         self.channel = self.channel_factory(name_of_the_worker, type(self), interpreter_executable = interpreter_executable, **options)
#     731
#     732         self._check_if_worker_is_up_to_date()
#
# /home/lex/amuse/src/amuse/rfi/channel.pyc in __init__(self, name_of_the_worker, legacy_interface_type, interpreter_executable, **options)
#    2172
#    2173         if not legacy_interface_type is None:
# -> 2174             self.full_name_of_the_worker = self.get_full_name_of_the_worker(legacy_interface_type)
#    2175         else:
#    2176             self.full_name_of_the_worker = self.name_of_the_worker
#
# /home/lex/amuse/src/amuse/rfi/channel.pyc in get_full_name_of_the_worker(self, type)
#    1165             found = os.path.exists(full_name_of_the_worker)
#    1166             if not found:
# -> 1167                 raise exceptions.CodeException("The worker application does not exist, it should be at: \n{0}".format('\n'.join(tried_workers)))
#    1168             else:
#    1169                 found = True
#
# CodeException: The worker application does not exist, it should be at:
# /home/lex/amuse/src/amuse/community/bhtree/bhtree_worker
# /home/lex/amuse/src/amuse/rfi/bhtree_worker
