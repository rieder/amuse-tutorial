# %%
"""
Basic example of AMUSE's "multiple" package.

Code developed by Steven McMillan & Simon Portegies Zwart.
Code adapted from the AMUSE textbook examples: 
https://github.com/amusecode/amuse/blob/master/examples/textbook/basic_multiples_si.py

Notebook by Francisca Concha-Ramírez.
"""

from __future__ import print_function
import numpy
from amuse.units import nbody_system, units, constants
from amuse.ic.plummer import new_plummer_model
from amuse.community.ph4.interface import ph4
from amuse.community.smalln.interface import SmallN
from amuse.community.kepler.interface import Kepler
from amuse.couple import multiples
# Out:
# /home/fran/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Awkward syntax here because multiples needs a function that resets
# and returns a small-N integrator.

###BOOKLISTSTART1###
SMALLN = None
def init_smalln(converter):
    global SMALLN
    SMALLN = SmallN(convert_nbody=converter)
def new_smalln():
    SMALLN.reset()
    return SMALLN
###BOOKLISTSTOP1###

def stop_smalln():
    global SMALLN
    SMALLN.stop()

# %%
def print_diagnostics(grav, E0=None):

    # Simple diagnostics.

    ke = grav.kinetic_energy
    pe = grav.potential_energy
    Nmul, Nbin, Emul = grav.get_total_multiple_energy()
    
    print('Time =', grav.get_time().in_(units.Myr))
    print('top-level kinetic energy =', ke)
    print('top-level potential energy =', pe)
    print('total top-level energy =', ke + pe)
    print(Nmul, 'multiples,', 'total energy =', Emul)
    
    E = ke + pe + Emul
    print('uncorrected total energy =', E)
    
    # Apply known corrections.
    
    Etid = grav.multiples_external_tidal_correction \
            + grav.multiples_internal_tidal_correction  # tidal error
    Eerr = grav.multiples_integration_energy_error  # integration error

    E -= Etid + Eerr
    print('corrected total energy =', E)

    if E0 is not None: print('relative energy error=', (E-E0)/E0)
    
    return E

# %%
def integrate_system(N, t_end, seed=None):

    total_mass = N | units.MSun
    length = 1 | units.parsec
    converter = nbody_system.nbody_to_si(total_mass, length)
    
    # Initialize gravity code for N-body system
    gravity = ph4(convert_nbody=converter)
    gravity.initialize_code()
    gravity.parameters.set_defaults()
    gravity.parameters.epsilon_squared = (0.0 | units.parsec) ** 2

    # Initialize stars
    if seed is not None: numpy.random.seed(seed)
    stars = new_plummer_model(N, convert_nbody=converter)
    stars.mass = total_mass / N
    stars.scale_to_standard(convert_nbody=converter,
                            smoothing_length_squared=gravity.parameters.epsilon_squared)
    
    # Set stellar ID. Important for internal bookkeeping within the module.
    id = numpy.arange(N)
    stars.id = id + 1
    stars.radius = 0.5 / N | units.parsec

    gravity.particles.add_particles(stars)

    # Set stopping condition: collision detection
    stopping_condition = gravity.stopping_conditions.collision_detection
    stopping_condition.enable()

    # Initalize smalln integrator
    init_smalln(converter)
    
    # Initialize Kepler code
    kep = Kepler(unit_converter=converter)
    kep.initialize_code()
    
    # Initialize code for multiples
    multiples_code = multiples.Multiples(gravity, new_smalln, kep, constants.G)
    multiples_code.neighbor_perturbation_limit = 0.05
    multiples_code.global_debug = 1

    # global_debug = 0: no output from multiples
    #               1: minimal output
    #               2: debugging output
    #               3: even more output

    print('multiples_code.neighbor_veto =', multiples_code.neighbor_veto)
    print('multiples_code.neighbor_perturbation_limit =', multiples_code.neighbor_perturbation_limit)
    print('multiples_code.retain_binary_apocenter =', multiples_code.retain_binary_apocenter)
    print('multiples_code.wide_perturbation_limit =', multiples_code.wide_perturbation_limit)

    time = numpy.sqrt(length**3/(constants.G*total_mass))
    print('time unit =', time.in_(units.Myr))

    E0 = print_diagnostics(multiples_code)
    multiples_code.evolve_model(t_end)
    print_diagnostics(multiples_code, E0)

    gravity.stop()
    kep.stop()
    stop_smalln()

# %%
N = 100
t_end = 10.0 | units.Myr
integrate_system(N, t_end, 42)
# Out:
# multiples_code.neighbor_veto = True
# multiples_code.neighbor_perturbation_limit = 0.05
# multiples_code.retain_binary_apocenter = True
# multiples_code.wide_perturbation_limit = 0.01
# time unit = 1.49080299942 Myr
# Time = 0.0 Myr
# top-level kinetic energy = 2.13908733108e+37 m**2 * kg * s**-2
# top-level potential energy = -4.27817466217e+37 m**2 * kg * s**-2
# total top-level energy = -2.13908733108e+37 m**2 * kg * s**-2
# 0 multiples, total energy = zero
# uncorrected total energy = -2.13908733108e+37 m**2 * kg * s**-2
# corrected total energy = -2.13908733108e+37 m**2 * kg * s**-2
#
# Evolve model to 10.0 Myr starting at 0.0 s
#
# interaction at time 1.64014864187e+13 s
# initial top-level: 84 (1.54283879064e+14 m) 50 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 6.39697180347e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 84 (1.54283879064e+14 m) 50 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 6.39697180347e+35 m**2 * kg * s**-2
#
# interaction at time 2.66064728915e+13 s
# initial top-level: 38 (1.54283879064e+14 m) 83 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 5.75261167964e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 38 (1.54283879064e+14 m) 83 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 5.75261167964e+35 m**2 * kg * s**-2
#
# interaction at time 2.86566586938e+13 s
# initial top-level: 6 (1.54283879064e+14 m) 83 (1.54283879064e+14 m)
# /home/fran/amuse/src/amuse/units/generic_unit_converter.py:189: RuntimeWarning: overflow encountered in double_scalars
#   return new_quantity(number * factor, new_unit)
# /home/fran/amuse/src/amuse/units/generic_unit_converter.py:227: RuntimeWarning: overflow encountered in double_scalars
#   return new_quantity(number * factor, new_unit)
# M = 3.97784e+30 kg  Etop = 4.74064212517e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 6 (1.54283879064e+14 m) 83 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 4.74064212517e+35 m**2 * kg * s**-2
#
# interaction at time 4.03490348663e+13 s
# initial top-level: 16 (1.54283879064e+14 m) 30 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 4.29324257225e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 16 (1.54283879064e+14 m) 30 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 4.29324257225e+35 m**2 * kg * s**-2
#
# interaction at time 9.22870751922e+13 s
# initial top-level: 22 (1.54283879064e+14 m) 83 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 2.3307543023e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 22 (1.54283879064e+14 m) 83 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 2.3307543023e+35 m**2 * kg * s**-2
#
# interaction at time 9.82251483565e+13 s
# initial top-level: 92 (1.54283879064e+14 m) 93 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 6.19834690169e+34 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 92 (1.54283879064e+14 m) 93 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 6.19834690169e+34 m**2 * kg * s**-2
#
# interaction at time 1.00108792455e+14 s
# initial top-level: 83 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 3.23667274019e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 83 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 3.23667274019e+35 m**2 * kg * s**-2
#
# interaction at time 1.01521525529e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 1.32464471785e+33 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 41 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 1.32464471785e+33 m**2 * kg * s**-2
#
# interaction at time 1.03129514393e+14 s
# initial top-level: 96 (1.54283879064e+14 m) 22 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 7.40957265368e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 96 (1.54283879064e+14 m) 22 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 7.40957265368e+35 m**2 * kg * s**-2
#
# interaction at time 1.1964585716e+14 s
# initial top-level: 59 (1.54283879064e+14 m) 96 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -8.9293151511e+34 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (59,96)
# final top-level: 59 (1.54283879064e+14 m) 96 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -1.02191708062e+36 m**2 * kg * s**-2
#
# interaction at time 1.24659336727e+14 s
# initial top-level: 83 (1.54283879064e+14 m) 7 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 2.75949970726e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 83 (1.54283879064e+14 m) 7 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 2.75949970726e+35 m**2 * kg * s**-2
#
# interaction at time 1.25181933108e+14 s
# initial top-level: 90 (1.54283879064e+14 m) 41 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 2.64792044705e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 90 (1.54283879064e+14 m) 41 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 2.64792044705e+35 m**2 * kg * s**-2
#
# interaction at time 1.28179683777e+14 s
# initial top-level: 43 (1.54283879064e+14 m) 7 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 4.51548247029e+34 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 43 (1.54283879064e+14 m) 7 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 4.51548247029e+34 m**2 * kg * s**-2
#
# interaction at time 1.38895780996e+14 s
# initial top-level: 59 (1.54283879064e+14 m) 96 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -8.84974625826e+34 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (59,96)
# final top-level: 59 (1.54283879064e+14 m) 96 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -3.11290319839e+36 m**2 * kg * s**-2
#
# interaction at time 1.48784912513e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 99 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -2.97030774562e+34 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (14,99)
# final top-level: 14 (1.54283879064e+14 m) 99 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -5.22529385703e+35 m**2 * kg * s**-2
#
# interaction at time 1.60902257171e+14 s
# initial top-level: 59 (1.54283879064e+14 m) 96 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -8.65423284261e+34 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (59,96)
# final top-level: 59 (1.54283879064e+14 m) 96 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -9.62937312553e+35 m**2 * kg * s**-2
#
# interaction at time 1.70171164412e+14 s
# initial top-level: 99 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -9.96856517366e+34 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (99,14)
# final top-level: 99 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -3.51080711222e+36 m**2 * kg * s**-2
#
# interaction at time 1.99987872215e+14 s
# initial top-level: 96 (1.54283879064e+14 m) 50 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 5.85731106973e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 96 (1.54283879064e+14 m) 50 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 5.85731106973e+35 m**2 * kg * s**-2
#
# interaction at time 2.05811089032e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 99 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -9.2705888948e+34 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (14,99)
# final top-level: 14 (1.54283879064e+14 m) 99 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -1.62037865181e+36 m**2 * kg * s**-2
#
# interaction at time 2.26818314984e+14 s
# initial top-level: 99 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 3.62105544332e+34 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 99 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 3.62105544332e+34 m**2 * kg * s**-2
#
# interaction at time 2.32997586478e+14 s
# initial top-level: 61 (1.54283879064e+14 m) 27 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 4.02525936142e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 61 (1.54283879064e+14 m) 27 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 4.02525936142e+35 m**2 * kg * s**-2
#
# interaction at time 2.35145400176e+14 s
# initial top-level: 99 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -6.95813471534e+34 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (99,14)
# final top-level: 99 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -7.78282066784e+35 m**2 * kg * s**-2
#
# interaction at time 2.37408070221e+14 s
# initial top-level: 16 (1.54283879064e+14 m) 78 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 7.00700627881e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 16 (1.54283879064e+14 m) 78 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 7.00700627881e+35 m**2 * kg * s**-2
#
# interaction at time 2.41175358418e+14 s
# initial top-level: 99 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -1.10758569526e+34 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (99,14)
# final top-level: 99 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -3.76199734131e+35 m**2 * kg * s**-2
#
# interaction at time 2.45356129466e+14 s
# initial top-level: 38 (1.54283879064e+14 m) 99 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 1.44533819951e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 38 (1.54283879064e+14 m) 99 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 1.44533819951e+35 m**2 * kg * s**-2
# *** tidal correction = 0.0312139310872 KE ***
# interaction at time 2.46642520557e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 14 at distance 5.03170183601e+14 m pert = 0.226425160367
#
# interaction at time 2.46654006192e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 14 at distance 4.92860979274e+14 m pert = 0.226323746856
#
# interaction at time 2.46665491827e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 14 at distance 4.82478689296e+14 m pert = 0.227490180463
#
# interaction at time 2.46676977462e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 14 at distance 4.72024296646e+14 m pert = 0.230106698062
#
# interaction at time 2.46688463096e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 14 at distance 4.61499365636e+14 m pert = 0.234389808136
#
# interaction at time 2.46699948731e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 14 at distance 4.5090614719e+14 m pert = 0.240598182199
#
# interaction at time 2.46711434366e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 14 at distance 4.40247696115e+14 m pert = 0.24904244297
#
# interaction at time 2.46722920001e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 14 at distance 4.29528000688e+14 m pert = 0.260097277067
#
# interaction at time 2.46734405635e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 14 at distance 4.1875212502e+14 m pert = 0.274216386864
#
# interaction at time 2.4674589127e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 14 at distance 4.07926364724e+14 m pert = 0.291950899372
#
# interaction at time 2.46757376905e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 14 at distance 3.97058416931e+14 m pert = 0.3139719702
#
# interaction at time 2.46866490435e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 2.99957991986e+14 m pert = 0.872108645725
#
# interaction at time 2.46872233252e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.03566653439e+14 m pert = 0.759817762975
#
# interaction at time 2.4687797607e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.07196378157e+14 m pert = 0.659071623028
#
# interaction at time 2.46883718887e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.10842968597e+14 m pert = 0.568964384022
#
# interaction at time 2.46889461704e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.14502519174e+14 m pert = 0.48863729375
#
# interaction at time 2.46895204522e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.1817140529e+14 m pert = 0.41728014885
#
# interaction at time 2.46900947339e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.2184627184e+14 m pert = 0.354131667279
#
# interaction at time 2.46906690157e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.25524021369e+14 m pert = 0.298478998905
#
# interaction at time 2.46912432974e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.29201802122e+14 m pert = 0.249656565136
#
# interaction at time 2.46915304383e+14 s
# initial top-level: 33 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.31039877271e+14 m pert = 0.227611215555
#
# interaction at time 2.46918175791e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.32876996085e+14 m pert = 0.207044386842
#
# interaction at time 2.469210472e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.34712865902e+14 m pert = 0.187885369682
#
# interaction at time 2.46923918609e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.3654720721e+14 m pert = 0.170066032507
#
# interaction at time 2.46926790017e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.38379753296e+14 m pert = 0.153520743587
#
# interaction at time 2.46929661426e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.40210249896e+14 m pert = 0.138186290653
#
# interaction at time 2.46932532835e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.42038454858e+14 m pert = 0.124001798428
#
# interaction at time 2.46935404243e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.4386413781e+14 m pert = 0.11090864439
#
# interaction at time 2.46938275652e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.45687079831e+14 m pert = 0.0988503730327
#
# interaction at time 2.46941147061e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.47507073136e+14 m pert = 0.0877726088023
#
# interaction at time 2.46944018469e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.49323920769e+14 m pert = 0.0776229678182
#
# interaction at time 2.46946889878e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.51137436296e+14 m pert = 0.0683509684228
#
# interaction at time 2.46949761287e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.52947443516e+14 m pert = 0.0599079405315
#
# interaction at time 2.46952632696e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# encounter vetoed by 41 at distance 3.54753776179e+14 m pert = 0.052246933704
#
# interaction at time 2.46955504104e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 7.32638900634e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 14 (1.54283879064e+14 m) 33 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 7.32638900634e+35 m**2 * kg * s**-2
#
# interaction at time 2.47630285146e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 41 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -5.95043099319e+35 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (14,41)
# final top-level: 14 (1.54283879064e+14 m) 41 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -5.95501740089e+36 m**2 * kg * s**-2
#
# interaction at time 2.48227538152e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 41 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -5.90837471915e+35 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (14,41)
# final top-level: 14 (1.54283879064e+14 m) 41 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -7.34508027262e+36 m**2 * kg * s**-2
#
# interaction at time 2.48239023787e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -5.90752147845e+35 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (41,14)
# final top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -7.54275717572e+36 m**2 * kg * s**-2
#
# interaction at time 2.48240459492e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -5.90741779124e+35 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (41,14)
# final top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -7.5692373304e+36 m**2 * kg * s**-2
# interaction at time 2.48241895196e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -5.90731472186e+35 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (41,14)
# final top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -7.59613978783e+36 m**2 * kg * s**-2
#
# interaction at time 2.482433309e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -5.90721228005e+35 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (41,14)
# final top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -7.62347434838e+36 m**2 * kg * s**-2
#
# interaction at time 2.48244766605e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -5.90711047568e+35 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (41,14)
# final top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -7.65125113031e+36 m**2 * kg * s**-2
#
# interaction at time 2.48246202309e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -5.90700931879e+35 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (41,14)
# final top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -7.67948058293e+36 m**2 * kg * s**-2
#
# interaction at time 2.48247638013e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -5.90690881957e+35 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (41,14)
# final top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -7.70817350048e+36 m**2 * kg * s**-2
#
# interaction at time 2.48249073718e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -5.90680898838e+35 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (41,14)
# final top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -7.73734103666e+36 m**2 * kg * s**-2
#
# interaction at time 2.48250509422e+14 s
# initial top-level: 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -5.90670983572e+35 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# accepting lightly perturbed or repeat binary (41,14)
# increasing radius for 0 from 3.08567758128e+14 m to 4.46985479599e+14 m
# final top-level: 0 (4.46985479599e+14 m)
# M = 3.97784e+30 kg Etop = -7.76699471996e+36 m**2 * kg * s**-2
#
# interaction at time 2.52373852296e+14 s
# initial top-level: 50 (1.54283879064e+14 m) 30 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 5.0545119179e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 50 (1.54283879064e+14 m) 30 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 5.0545119179e+35 m**2 * kg * s**-2
#
# interaction at time 2.610684778e+14 s
# initial top-level: 84 (1.54283879064e+14 m) 69 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -5.01666452885e+34 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (84,69)
# final top-level: 84 (1.54283879064e+14 m) 69 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -5.1796614901e+35 m**2 * kg * s**-2
#
# interaction at time 2.61803558423e+14 s
# initial top-level: 50 (1.54283879064e+14 m) 79 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 5.0362473923e+34 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 50 (1.54283879064e+14 m) 79 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 5.0362473923e+34 m**2 * kg * s**-2
#
# interaction at time 2.62952121898e+14 s
# initial top-level: 78 (1.54283879064e+14 m) 98 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 5.0765298826e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 78 (1.54283879064e+14 m) 98 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 5.0765298826e+35 m**2 * kg * s**-2
#
# interaction at time 2.64146627912e+14 s
# initial top-level: 40 (1.54283879064e+14 m) 38 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 2.01548353423e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 40 (1.54283879064e+14 m) 38 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 2.01548353423e+35 m**2 * kg * s**-2
#
# interaction at time 2.82730384932e+14 s
# initial top-level: 81 (1.54283879064e+14 m) 91 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 2.02895656475e+36 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 81 (1.54283879064e+14 m) 91 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 2.02895656475e+36 m**2 * kg * s**-2
#
# interaction at time 2.83138124966e+14 s
# initial top-level: 86 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -3.7326730458e+34 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (86,40)
# final top-level: 86 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -3.82220623627e+35 m**2 * kg * s**-2
#
# interaction at time 2.83235752861e+14 s
# initial top-level: 61 (1.54283879064e+14 m) 1000001 (4.46985479599e+14 m)
# M = 5.96676e+30 kg  Etop = 1.23560778828e+35 m**2 * kg * s**-2
# after encounter: 1 single(s), 1 multiple(s)
# *** warning: dE_int mismatch ***
# splitting perturbed binary (41,14)
# final top-level: 61 (1.54283879064e+14 m) 41 (1.54283879064e+14 m) 14 (1.54283879064e+14 m)
# M = 5.96676e+30 kg Etop = -8.63132467611e+36 m**2 * kg * s**-2
# *** tidal correction = -0.0759940740072 KE ***
#
# interaction at time 2.83752606425e+14 s
# initial top-level: 7 (1.54283879064e+14 m) 61 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 2.68463934914e+34 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 7 (1.54283879064e+14 m) 61 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 2.68463934914e+34 m**2 * kg * s**-2
#
# interaction at time 2.84154603641e+14 s
# initial top-level: 14 (1.54283879064e+14 m) 41 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -5.09357375646e+35 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# accepting lightly perturbed or repeat binary (14,41)
# increasing radius for 0 from 3.08567758128e+14 m to 5.18342062962e+14 m
# final top-level: 0 (5.18342062962e+14 m)
# M = 3.97784e+30 kg Etop = -6.27184473116e+36 m**2 * kg * s**-2
#
# interaction at time 2.90494674021e+14 s
# initial top-level: 5 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 3.68047345497e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 5 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 3.68047345497e+35 m**2 * kg * s**-2
#
# interaction at time 2.96283433934e+14 s
# initial top-level: 20 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 8.32380827505e+35 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 20 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 8.32380827505e+35 m**2 * kg * s**-2
#
# interaction at time 2.96811773132e+14 s
# initial top-level: 7 (1.54283879064e+14 m) 1000001 (5.18342062962e+14 m)
# M = 5.96676e+30 kg  Etop = -1.03977356908e+35 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (0,41)
# increasing radius for 0 from 3.08567758128e+14 m to 4.56215324286e+14 m
# final top-level: 41 (1.54283879064e+14 m) 0 (4.56215324286e+14 m)
# M = 5.96676e+30 kg Etop = -8.03971010541e+36 m**2 * kg * s**-2
#
# interaction at time 3.07493413447e+14 s
# initial top-level: 1000002 (4.56215324286e+14 m) 19 (1.54283879064e+14 m)
# M = 5.96676e+30 kg  Etop = 2.2241154461e+35 m**2 * kg * s**-2
# after encounter: 1 single(s), 1 multiple(s)
# accepting lightly perturbed or repeat binary (7,14)
# increasing radius for 0 from 3.08567758128e+14 m to 4.97416270382e+14 m
# final top-level: 19 (1.54283879064e+14 m) 0 (4.97416270382e+14 m)
# M = 5.96676e+30 kg Etop = -5.79954260046e+36 m**2 * kg * s**-2
# *** tidal correction = 0.0102619267286 KE ***
# interaction at time 3.10255708604e+14 s
# initial top-level: 40 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 3.96330987006e+14 m pert = 0.450159516033
#
# interaction at time 3.10261451421e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 3.98194524186e+14 m pert = 0.400217843644
#
# interaction at time 3.10267194238e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 3.99999413338e+14 m pert = 0.354486413623
#
# interaction at time 3.10272937056e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.01745186828e+14 m pert = 0.312702463104
#
# interaction at time 3.10278679873e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.03431382606e+14 m pert = 0.274619410209
#
# interaction at time 3.10284422691e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.05057543301e+14 m pert = 0.240005538498
#
# interaction at time 3.10290165508e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.0662321544e+14 m pert = 0.208642761194
#
# interaction at time 3.10295908325e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.08127948804e+14 m pert = 0.180325455297
#
# interaction at time 3.10301651143e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.09571295944e+14 m pert = 0.154859355879
#
# interaction at time 3.1030739396e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.10952811905e+14 m pert = 0.132060501006
#
# interaction at time 3.10310265369e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.11620244811e+14 m pert = 0.121606369135
#
# interaction at time 3.10313136777e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.12272054187e+14 m pert = 0.111754217594
#
# interaction at time 3.10316008186e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.12908185148e+14 m pert = 0.102483502571
#
# interaction at time 3.10318879595e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.13528583019e+14 m pert = 0.0937741393964
#
# interaction at time 3.10321751003e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.14133193361e+14 m pert = 0.0856064729497
#
# interaction at time 3.10324622412e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.14721962018e+14 m pert = 0.0779612482667
#
# interaction at time 3.10327493821e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.15294835159e+14 m pert = 0.0708195812854
#
# interaction at time 3.1033036523e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.15851759344e+14 m pert = 0.0641629297101
#
# interaction at time 3.10333236638e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.16392681598e+14 m pert = 0.0579730640052
#
# interaction at time 3.10336108047e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# encounter vetoed by 50 at distance 4.16917549494e+14 m pert = 0.0522320385694
#
# interaction at time 3.10338979456e+14 s
# initial top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = 1.06883837399e+36 m**2 * kg * s**-2
# after encounter: 2 single(s), 0 multiple(s)
# final top-level: 48 (1.54283879064e+14 m) 40 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = 1.06883837399e+36 m**2 * kg * s**-2
#
# interaction at time 3.10583049194e+14 s
# initial top-level: 50 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# encounter vetoed by 40 at distance 5.73637734238e+14 m pert = 0.15326509917
#
# interaction at time 3.10594534829e+14 s
# initial top-level: 50 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# encounter vetoed by 40 at distance 5.880139525e+14 m pert = 0.133858251603
#
# interaction at time 3.10606020463e+14 s
# initial top-level: 50 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# encounter vetoed by 40 at distance 6.02260582135e+14 m pert = 0.117040991501
#
# interaction at time 3.10617506098e+14 s
# initial top-level: 50 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# encounter vetoed by 40 at distance 6.16382868712e+14 m pert = 0.102441090877
#
# interaction at time 3.10628991733e+14 s
# initial top-level: 50 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# encounter vetoed by 40 at distance 6.30385635323e+14 m pert = 0.0897472307902
#
# interaction at time 3.10640477368e+14 s
# initial top-level: 50 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# encounter vetoed by 40 at distance 6.44273327739e+14 m pert = 0.0786976260158
#
# interaction at time 3.10651963002e+14 s
# initial top-level: 50 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# encounter vetoed by 40 at distance 6.58050053877e+14 m pert = 0.0690710263643
#
# interaction at time 3.10663448637e+14 s
# initial top-level: 50 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# encounter vetoed by 40 at distance 6.71719618477e+14 m pert = 0.0606795486331
#
# interaction at time 3.10674934272e+14 s
# initial top-level: 50 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# encounter vetoed by 40 at distance 6.85285553746e+14 m pert = 0.053362929879
#
# interaction at time 3.10686419907e+14 s
# initial top-level: 50 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -2.70385728374e+35 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (50,48)
# final top-level: 50 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -4.48556970873e+36 m**2 * kg * s**-2
# *** tidal correction = 0.0724484011987 KE ***
#
# interaction at time 3.1463747826e+14 s
# initial top-level: 50 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# M = 3.97784e+30 kg  Etop = -2.42526322665e+35 m**2 * kg * s**-2
# after encounter: 0 single(s), 1 multiple(s)
# splitting perturbed binary (50,48)
# final top-level: 50 (1.54283879064e+14 m) 48 (1.54283879064e+14 m)
# M = 3.97784e+30 kg Etop = -2.95190679071e+36 m**2 * kg * s**-2
#
# Resolved 54 encounters
# Ignored 63 encounters
# Time = 10.0017740293 Myr
# top-level kinetic energy = 1.8414750327e+37 m**2 * kg * s**-2
# top-level potential energy = -3.93189506572e+37 m**2 * kg * s**-2
# total top-level energy = -2.09042003302e+37 m**2 * kg * s**-2
# 1 multiples, total energy = -5.30785518283e+35 m**2 * kg * s**-2
# uncorrected total energy = -2.14349858485e+37 m**2 * kg * s**-2
# corrected total energy = -2.13909133107e+37 m**2 * kg * s**-2
# relative energy error= 1.8699494241e-06
